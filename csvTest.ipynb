# %%
import numpy as np

# %%
# Out:
# array([['0.000000000000000000e+00', '3.881029321172458912e-01',
#         '2.410931291723514280e-01', ..., '4.575396819442366092e-01',
#         '1.424574239801451037e-01', '3.687702672478683774e-01'],
#        ['0.000000000000000000e+00', '0.000000000000000000e+00',
#         '2.256111270074805941e-01', ..., '3.881029321172458912e-01',
#         '1.770978158070741215e-01', '3.084698384335636256e-01'],
#        ['0.000000000000000000e+00', '0.000000000000000000e+00',
#         '0.000000000000000000e+00', ..., '2.410931291723514280e-01',
#         '6.528576353053677783e-02', '1.974398510035601517e-01'],
#        ...,
#        ['0.000000000000000000e+00', '0.000000000000000000e+00',
#         '0.000000000000000000e+00', ..., '0.000000000000000000e+00',
#         '1.424574239801451037e-01', '3.687702672478683774e-01'],
#        ['0.000000000000000000e+00', '0.000000000000000000e+00',
#         '0.000000000000000000e+00', ..., '0.000000000000000000e+00',
# ...
